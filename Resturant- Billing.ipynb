# %%
class Resturant:
    def __init__(self,r_name,menu):
        self.r_name = r_name
        self.menu = menu
        self.menu.menu()
        
class Menu:
    def __init__(self):
      self.amount = 0
      self.total_amount = {}

    def menu(self):
        user_input = input("""
        1. To order pizza
        2. To order burger
        3. To order noodle
        4. To order water and coldrink
        5. To exits......
        """)
        if user_input == "1":
            self.rmenu()
        elif user_input == "2":
            self.burger()
        elif user_input == "3":
            self.noodle()
        elif user_input == "4":
            self.other()
        else:
            self.total_bill()
            
    def rmenu(self):
        user_input = input("""
        1. Veg_Pizza
        2. Non_Veg_Pizza
        """)
        if user_input == "1":
            self.veg_pizza()
        elif user_input == "2":
            self.non_veg_pizza()
        else:
            print("exit")
            

    def veg_pizza(self):
        options = input("""
        1. Margherita  99
        2. Double Cheese Margherita  149
        3. Peppy Paneer  169
        4. Mexican Green Wave  199
        5. Paneer Makhni  229
        6. Deluxe Veggie  299
        """)

        if options == "1":
            self.amount = 99
            if "Margherita" in self.total_amount:
                self.total_amount["Margherita"]["quantity"] = self.total_amount["Margherita"]["quantity"] + 1 
                self.total_amount["Margherita"]["total_price"] = self.total_amount["Margherita"]["total_price"] + 99 
            else:
                self.total_amount["Margherita"] = {"quantity":1, "price per piece":99, "total_price":99}
            self.menu()
            

        if options == "2":
            self.amount = 149
            if "Double Cheese Margherita" in self.total_amount:
                self.total_amount["Double Cheese Margherita "]["quantity"] = self.total_amount["Double Cheese Margherita "]["quantity"] + 1 
                self.total_amount["Double Cheese Margherita "]["total_price"] = self.total_amount["Double Cheese Margherita "]["total_price"] + 149 
            else:
                self.total_amount["Double Cheese Margherita"] = {"quantity":1, "price per piece":149, "total_price":149}
            self.menu()

        if options == "3":
            self.amount = 169
            if "Peppy Paneer" in self.total_amount:
                self.total_amount["Peppy Paneer"]["quantity"] = self.total_amount["Peppy Paneer"]["quantity"] + 1 
                self.total_amount["Peppy Paneer"]["total_price"] = self.total_amount["Peppy Paneer"]["total_price"] + 169 
            else:
                self.total_amount["Peppy Paneer"] = {"quantity":1, "price per piece":169, "total_price":169}
            self.menu()
            
        if options == "4":
            self.amount = 199
            if "Mexican Green Wave" in self.total_amount:
                self.total_amount["Mexican Green Wave  "]["quantity"] = self.total_amount["Mexican Green Wave  "]["quantity"] + 1 
                self.total_amount["Mexican Green Wave  "]["total_price"] = self.total_amount["Mexican Green Wave  "]["total_price"] + 199 
            else:
                self.total_amount["Mexican Green Wave  "] = {"quantity":1, "price per piece":199, "total_price":199}
            self.menu()

        if options == "5":
            self.amount = 229
            if "Paneer Makhni" in self.total_amount:
                self.total_amount["Paneer Makhni"]["quantity"] = self.total_amount["Paneer Makhni"]["quantity"] + 1 
                self.total_amount["Paneer Makhni"]["total_price"] = self.total_amount["Paneer Makhni"]["total_price"] + 229 
            else:
                self.total_amount["Paneer Makhni"] = {"quantity":1, "price per piece":229, "total_price":229}
            self.menu()
            
        if options == "6":
            self.amount = 299
            if "Peppy Paneer" in self.total_amount:
                self.total_amount["Deluxe Veggie"]["quantity"] = self.total_amount["Deluxe Veggie"]["quantity"] + 1 
                self.total_amount["Deluxe Veggie"]["total_price"] = self.total_amount["Deluxe Veggie"]["total_price"] + 299 
            else:
                self.total_amount["Deluxe Veggie"] = {"quantity":1, "price per piece":299, "total_price":299}  
            self.menu()

    # def total_bill(self):
    #     print("your amount is: {}".format(sum(self.total_amount)))
            
    def non_veg_pizza(self):
        options = input("""
        1. Chicken Golden Delight 99
        2. Chicken Dominator  149
        3. Pepper Barbecue Chicken   169
        4. Double Cheese Noodle  199
        5. Chicken Pepperoni   229
        6. Chicken Fiesta     299
        """)
        if options == "1":
            self.amount = 99
            if "Chicken Golden Delight" in self.total_amount:
                self.total_amount["Chicken Golden Delight"]["quantity"] = self.total_amount["Chicken Golden Delight"]["quantity"] + 1 
                self.total_amount["Chicken Golden Delight"]["total_price"] = self.total_amount["Chicken Golden Delight"]["total_price"] + 99 
            else:
                self.total_amount["Chicken Golden Delight"] = {"quantity":1, "price per piece":99, "total_price":99}   
            self.menu()

        if options == "2":
            self.amount = 149
            if "Chicken Dominator" in self.total_amount:
                self.total_amount["Chicken Dominator"]["quantity"] = self.total_amount["Chicken Dominator"]["quantity"] + 1 
                self.total_amount["Chicken Dominator"]["total_price"] = self.total_amount["Chicken Dominator"]["total_price"] + 149 
            else:
                self.total_amount["Chicken Dominator"] = {"quantity":1, "price per piece":149, "total_price":149}    
            self.menu()

        if options == "3":
            self.amount = 169
            if "Pepper Barbecue Chicken" in self.total_amount:
                self.total_amount["Pepper Barbecue Chicken"]["quantity"] = self.total_amount["Pepper Barbecue Chicken"]["quantity"] + 1 
                self.total_amount["Pepper Barbecue Chicken"]["total_price"] = self.total_amount["Double Cheese Noodle"]["total_price"] + 169 
            else:
                self.total_amount["Pepper Barbecue Chicken"] = {"quantity":1, "price per piece":169, "total_price":169}  
            self.menu()
            
        if options == "4":
            self.amount = 199
            if "Double Cheese Noodle  " in self.total_amount:
                self.total_amount["Double Cheese Noodle"]["quantity"] = self.total_amount["Double Cheese Noodle"]["quantity"] + 1 
                self.total_amount["Double Cheese Noodle"]["total_price"] = self.total_amount["Double Cheese Noodle  "]["total_price"] + 199 
            else:
                self.total_amount["Double Cheese Noodle"] = {"quantity":1, "price per piece":199, "total_price":199}
            self.menu()

        if options == "5":
            self.amount = 229
            if "Chicken Pepperoni" in self.total_amount:
                self.total_amount["Chicken Pepperoni"]["quantity"] = self.total_amount["Chicken Pepperoni"]["quantity"] + 1 
                self.total_amount["Chicken Pepperoni"]["total_price"] = self.total_amount["Chicken Pepperoni"]["total_price"] + 229 
            else:
                self.total_amount["Chicken Pepperoni"] = {"quantity":1, "price per piece":229, "total_price":229} 
            self.menu()
            
        if options == "6":
            self.amount = 299
            if " Chicken Fiesta" in self.total_amount:
                self.total_amount[" Chicken Fiesta"]["quantity"] = self.total_amount[" Chicken Fiesta"]["quantity"] + 1 
                self.total_amount[" Chicken Fiesta"]["total_price"] = self.total_amount[" Chicken Fiesta"]["total_price"] + 299 
            else:
                self.total_amount[" Chicken Fiesta"] = {"quantity":1, "price per piece":299, "total_price":299}
            self.menu()

    def burger(self):
        options = input("""
        1. Simple Burger 39
        2. Cheese Burger  49
        3. Double Cheese Burger 69
        4. Paaty Burger 59
        5. Noodle Burger 55
        6. Hot Burger 99
        """)
        if options == "1":
            self.amount = 39
            if "Simple Burger" in self.total_amount:
                self.total_amount["Simple Burger"]["quantity"] = self.total_amount["Simple Burger"]["quantity"] + 1 
                self.total_amount["Simple Burger"]["total_price"] = self.total_amount["Simple Burger"]["total_price"] + 39 
            else:
                self.total_amount["Simple Burger"] = {"quantity":1, "price per piece":39, "total_price":39}   
            self.menu()

        if options == "2":
            self.amount = 49
            if "Cheese Burger" in self.total_amount:
                self.total_amount["Cheese Burger"]["quantity"] = self.total_amount["Cheese Burger"]["quantity"] + 1 
                self.total_amount["Cheese Burger"]["total_price"] = self.total_amount["Cheese Burger"]["total_price"] + 49 
            else:
                self.total_amount["Cheese Burger"] = {"quantity":1, "price per piece":49, "total_price":49}     
            self.menu()

        if options == "3":
            self.amount = 69
            if "Double Cheese Burger" in self.total_amount:
                self.total_amount["Double Cheese Burger"]["quantity"] = self.total_amount["Double Cheese Burger"]["quantity"] + 1 
                self.total_amount["Double Cheese Burger"]["total_price"] = self.total_amount["Double Cheese Burger"]["total_price"] + 69 
            else:
                self.total_amount["Double Cheese Burger"] = {"quantity":1, "price per piece":69, "total_price":69} 
            self.menu()
            
        if options == "4":
            self.amount = 59
            if "Paaty Burger" in self.total_amount:
                self.total_amount["Paaty Burger"]["quantity"] = self.total_amount["Paaty Burger"]["quantity"] + 1 
                self.total_amount["Paaty Burger"]["total_price"] = self.total_amount["Paaty Burger"]["total_price"] + 59 
            else:
                self.total_amount["Paaty Burger"] = {"quantity":1, "price per piece":59, "total_price":59}  
            self.menu()

        if options == "5":
            self.amount = 55
            if "Noodle Burger" in self.total_amount:
                self.total_amount["Noodle Burger"]["quantity"] = self.total_amount["Noodle Burger"]["quantity"] + 1 
                self.total_amount["Noodle Burger"]["total_price"] = self.total_amount["Noodle Burger"]["total_price"] + 55 
            else:
                self.total_amount["Noodle Burger"] = {"quantity":1, "price per piece":55, "total_price":55}    
            self.menu()
            
        if options == "6":
            self.amount = 99
            if "Hot Burger" in self.total_amount:
                self.total_amount["Hot Burger"]["quantity"] = self.total_amount["Hot Burger"]["quantity"] + 1 
                self.total_amount["Hot Burger"]["total_price"] = self.total_amount["Hot Burger"]["total_price"] + 99 
            else:
                self.total_amount["Hot Burger"] = {"quantity":1, "price per piece":99, "total_price":99}    
            self.menu()

    def noodle(self):
        options = input("""
        1. Noodle 39
        2. Cheese Noodle 49
        3. Double Cheese Noodle 69
        4. Mix Noodle 79
        5. Spicy Noodle 55
        """)
        if options == "1":
            self.amount = 39
            if "Noodle" in self.total_amount:
                self.total_amount["Noodle"]["quantity"] = self.total_amount["Noodle"]["quantity"] + 1 
                self.total_amount["Noodle"]["total_price"] = self.total_amount["Noodle"]["total_price"] + 39 
            else:
                self.total_amount["Noodle"] = {"quantity":1, "price per piece":39, "total_price":39}      
            self.menu()

        if options == "2":
            self.amount = 49
            if "Cheese Noodle" in self.total_amount:
                self.total_amount["Cheese Noodle"]["quantity"] = self.total_amount["Cheese Noodle"]["quantity"] + 1 
                self.total_amount["Cheese Noodle"]["total_price"] = self.total_amount["Cheese Noodle  "]["total_price"] + 49 
            else:
                self.total_amount["Cheese Noodle"] = {"quantity":1, "price per piece":49, "total_price":49}    
            self.menu()

        if options == "3":
            self.amount = 69
            if "Double Cheese Noodle" in self.total_amount:
                self.total_amount["Double Cheese Noodle"]["quantity"] = self.total_amount["Double Cheese Noodle"]["quantity"] + 1 
                self.total_amount["Double Cheese Noodle"]["total_price"] = self.total_amount["Double Cheese Noodle  "]["total_price"] + 69 
            else:
                self.total_amount["Double Cheese Noodle"] = {"quantity":1, "price per piece":69, "total_price":69} 
            self.menu()
            
        if options == "4":
            self.amount = 79
            if "Mix Noodle" in self.total_amount:
                self.total_amount["Mix Noodle"]["quantity"] = self.total_amount[" Mix Noodle"]["quantity"] + 1 
                self.total_amount["Mix Noodle"]["total_price"] = self.total_amount[" Mix Noodle"]["total_price"] + 79 
            else:
                self.total_amount[" Mix Noodle"] = {"quantity":1, "price per piece":79, "total_price":79} 
            self.menu()

        if options == "5":
            self.amount = 55
            if "Spicy Noodle" in self.total_amount:
                self.total_amount["Spicy Noodle"]["quantity"] = self.total_amount["Spicy Noodle"]["quantity"] + 1 
                self.total_amount["Spicy Noodle"]["total_price"] = self.total_amount["Spicy Noodle"]["total_price"] + 55 
            else:
                self.total_amount["Spicy Noodle"] = {"quantity":1, "price per piece":55, "total_price":55}
            self.menu()

    def other(self):
        options = input("""
        1. Water bottle 20
        2. Coldrink 69
        3. Sweet Lassi 59
        4. Spicy Lassi 39
        5. Coffee 99
        6. Tea 30
        7. Mojito 149
        8. Shake 139
        9. Cold Coffee 89
        """)
        if options == "1":
            self.amount = 20
            if "Water bottle" in self.total_amount:
                self.total_amount["Water bottle"]["quantity"] = self.total_amount["Water bottle"]["quantity"] + 1 
                self.total_amount["Water bottle"]["total_price"] = self.total_amount["Water bottle"]["total_price"] + 20 
            else:
                self.total_amount["Water bottle"] = {"quantity":1, "price per piece":20, "total_price":20}   
            self.menu()

        if options == "2":
            self.amount = 69
            if "Coldrink" in self.total_amount:
                self.total_amount["Coldrink"]["quantity"] = self.total_amount["Coldrink"]["quantity"] + 1 
                self.total_amount["Coldrink"]["total_price"] = self.total_amount["Coldrink"]["total_price"] + 69 
            else:
                self.total_amount["Coldrink"] = {"quantity":1, "price per piece":69, "total_price":69}  
            self.menu()

        if options == "3":
            self.amount = 59
            if "Sweet Lassi" in self.total_amount:
                self.total_amount["Sweet Lassi"]["quantity"] = self.total_amount["Sweet Lassi"]["quantity"] + 1 
                self.total_amount["Sweet Lassi"]["total_price"] = self.total_amount["Sweet Lassi"]["total_price"] + 59 
            else:
                self.total_amount["Sweet Lassi"] = {"quantity":1, "price per piece":59, "total_price":59} 
            self.menu()
            
        if options == "4":
            self.amount = 39
            if "Spicy Lassi" in self.total_amount:
                self.total_amount["Spicy Lassi"]["quantity"] = self.total_amount["Spicy Lassi"]["quantity"] + 1 
                self.total_amount["Spicy Lassi"]["total_price"] = self.total_amount["Spicy Lassi"]["total_price"] + 39 
            else:
                self.total_amount["Spicy Lassi"] = {"quantity":1, "price per piece":39, "total_price":39}  
            self.menu()

        if options == "5":
            self.amount = 99
            if "Coffee" in self.total_amount:
                self.total_amount["Coffee"]["quantity"] = self.total_amount["Coffee"]["quantity"] + 1 
                self.total_amount["Coffee"]["total_price"] = self.total_amount["Coffee"]["total_price"] + 99 
            else:
                self.total_amount["Coffee"] = {"quantity":1, "price per piece":99, "total_price":99} 
            self.menu()
            
        if options == "6":
            self.amount = 30
            if "Tea" in self.total_amount:
                self.total_amount["Tea"]["quantity"] = self.total_amount["Tea"]["quantity"] + 1 
                self.total_amount["Tea"]["total_price"] = self.total_amount["Tea"]["total_price"] + 30 
            else:
                self.total_amount["Tea"] = {"quantity":1, "price per piece":30, "total_price":30} 
            self.menu()

        if options == "7":
            self.amount = 149
            if "Mojito" in self.total_amount:
                self.total_amount["Mojito"]["quantity"] = self.total_amount["Mojito"]["quantity"] + 1 
                self.total_amount["Mojito"]["total_price"] = self.total_amount["Mojito"]["total_price"] + 149 
            else:
                self.total_amount["Mojito"] = {"quantity":1, "price per piece":149, "total_price":149} 
            self.menu()

        if options == "8":
            self.amount = 139
            if "Shake" in self.total_amount:
                self.total_amount["Shake"]["quantity"] = self.total_amount["Shake"]["quantity"] + 1 
                self.total_amount["Shake"]["total_price"] = self.total_amount["Shake"]["total_price"] + 139 
            else:
                self.total_amount["Shake"] = {"quantity":1, "price per piece":139, "total_price":139}    
            self.menu()

        if options == "9":
            self.amount = 89
            if "Cold Coffee" in self.total_amount:
                self.total_amount["Cold Coffee"]["quantity"] = self.total_amount["Cold Coffee"]["quantity"] + 1 
                self.total_amount["Cold Coffee"]["total_price"] = self.total_amount["Cold Coffee"]["total_price"] + 89 
            else:
                self.total_amount["Cold Coffee"] = {"quantity":1, "price per piece":89, "total_price":89}   
            self.menu()
            
    def total_bill(self):
        # print(self.total_amount)
        if self.total_amount == {}:
            print("thanks for visiting our resturant: ")
        else:
            print(self.total_amount)
            tp = []
            for i in self.total_amount:
                tp.append(self.total_amount[i]["total_price"])
            print("Your payable amount is: ",sum(tp))

# %%
me = Menu()
res = Resturant("Zomato",me)
# Out:
#         1. To order pizza
#         2. To order burger
#         3. To order noodle
#         4. To order water and coldrink
#         5. To exits......
#          5
# thanks for visiting our resturant:

# %%
data = {'Margherita': {'quantity': 2, 'price per piece': 99, 'total_price': 198}, 'Double Cheese Margherita': {'quantity': 1, 'price per piece': 149, 'total_price': 149}, 'Simple Burger': {'quantity': 1, 'price per piece': 39, 'total_price': 39}}
tp = []
for i in data:
    tp.append(data[i]["total_price"])
print(sum(tp))
# Out:
# 386
